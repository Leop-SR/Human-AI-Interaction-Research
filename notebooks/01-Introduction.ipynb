# %% [markdown]
# # From Statistical Estimation to Bayesian Classification: Modeling Human-AI Interaction

# %% [markdown]
# ### Research question
# Can we model and predict levels of emotional dependence on AI based on behavioral and usage patterns?
